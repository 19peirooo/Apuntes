# %% [markdown]
# # **Laboratorio 5**

# %% [markdown]
# Este laboratorio consta de implementar una libreria de difenciación automatica. Para ello implementaremos las funciones de suma, resta, multiplicacion y division aparte de funciones elementales

# %% [markdown]
# ## _Librerias y Dependencias_

# %%
import numpy as np

# %% [markdown]
# ## a) _Clase de Numeros Duales y Funciones Seno, Coseno y Exponencial_

# %% [markdown]
# ### **Clase**

# %% [markdown]
# $\bar{a} = a + a'd$
# $\bar{b} = b + b'd$

# %% [markdown]
# **Suma:** $(\bar{a} + \bar{b}) = (a + b, a' + b')$
# **Resta:** $(\bar{a} - \bar{b}) = (a - b, a' - b')$
# **Multiplicación:** $(\bar{a} · \bar{b}) = (ab, ab' + a'b)$
# **División:** $(\frac{\bar{a}}{\bar{b}}) = (\frac{a}{b}, \frac{a'b - b'a}{b^2})$

# %%
class Dual:
    """Número dual a + b·d con d^2 = 0.

    Atributos:
        value : parte real, valor f(x).
        deriv : parte dual, valor f'(x).
    """

    def __init__(self, value, deriv):
        self.value = value
        self.deriv = deriv

    def __add__(self, other):
        return Dual(self.value + other.value, self.deriv + other.deriv)

    def __sub__(self, other):
        return Dual(self.value - other.value, self.deriv - other.deriv)

    def __mul__(self, other):
        return Dual(self.value * other.value, (self.value * other.deriv) + (self.deriv * other.value))

    def __truediv__(self, other):
        return Dual (self.value / other.value, ((self.deriv * other.value)-(self.value*other.deriv))/(other.value**2))

# %% [markdown]
# ### **Funcion Seno**

# %% [markdown]
# $sen(\bar{a}) = (sen(a), a'cos(a))$

# %%
def sin(d):
    return Dual(np.sin(d.value), d.deriv * np.cos(d.value))

# %% [markdown]
# ### **Funcion Coseno**

# %% [markdown]
# $cos(\bar{a}) = (cos(a), -a'sen(a))$

# %%
def cos(d):
    return Dual(np.cos(d.value), -d.deriv * np.sin(d.value) )

# %% [markdown]
# ### **Funcion Exponencial**

# %% [markdown]
# $e^{\bar{a}} = (e^a, a'e^a)$

# %%
def exp(d):
    return Dual(np.exp(d.value), d.deriv * np.exp(d.value))

# %% [markdown]
# ## b) _Calcular f(0.5) y f'(0.5) para_ $f(x) = e^{sin(2x)}$

# %%
x0 = 0.5
x = Dual(x0,1)
dual2 = Dual(2,0)

# %% [markdown]
# **Paso 1**: Hacer 2x
# **Paso 2**: Hacer sen(2x)
# **Paso 3**: Hacer $e^{sen(2x)}$

# %%
# Paso 1
dual2x = dual2 * x

# %%
# Paso 2
dual_sin2x = sin(dual2x)

# %%
#Paso 3
result = exp(dual_sin2x)

# %%
print(f"f({x0}) = {result.value}")
print(f"f'({x0}) = {result.deriv}")

# %% [markdown]
# ## _c) Calcular Analiticamente f'(0.5) y mostrar el error absoluto_

# %%
f = lambda x: np.exp(np.sin(2*x))
df = lambda x: 2*np.cos(2*x)*np.exp(np.sin(2*x))

# %%
f_x = f(x0)
df_x = df(x0)

err_fx = np.abs(result.value - f_x)
err_dfx = np.abs(result.deriv - df_x)

# %%
print(f"f_dual({x0}) = {result.value}. f({x0}) = {f_x}. Error Absoluto: {err_fx}")
print(f"f'_dual({x0}) = {result.deriv}. f'({x0}) = {df_x}. Error Absoluto: {err_dfx}")
