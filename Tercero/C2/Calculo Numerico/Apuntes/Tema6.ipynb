# %% [markdown]
# # <center>**Tema 6 - Integración Numerica**</center>

# %% [markdown]
# ## <center>**Regla del Punto Medio**</center>

# %% [markdown]
# ### _Caso Simple_

# %% [markdown]
# Un unico intervalo e un unico nodo, el punto medio.
#
# Aproximamos el area debajo de la curva mediante rectangulos de base (b-a) y altura f($\frac{b-a}{2}$)
#
# $$
# I[f] = I_0[f] = (b-a)f(\frac{b-a}{2})
# $$

# %% [markdown]
# ### _Caso Compuesto_

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <center>**Newton-Cotes**</center>

# %% [markdown]
# Tomamos N+1 nodos equiespaciados y aproximamos por su polinomio interpolador de lagrange

# %% [markdown]
# ![image.png](attachment:image.png)
